# %%
import numpy as np
import matplotlib.pyplot as plt

x1,y1 = np.loadtxt("/home/satyam/Documents/BiomolTher/rmsf/rmsf_bacopasaponin_d_42.csv", unpack=True, delimiter=",")
x2,y2 = np.loadtxt("/home/satyam/Documents/BiomolTher/rmsf/rmsf_bacopasaponin_g_run17.csv", unpack=True, delimiter=",")
x3,y3 = np.loadtxt("/home/satyam/Documents/BiomolTher/rmsf/rmsf_p75ntr_ab42.csv", unpack=True, delimiter=",")

plt.figure(figsize=(18,10))
plt.plot(x1,y1, 'r', label="Bacopasaponin D", linewidth=3.0)
plt.plot(x2,y2, 'g', label="Bacopasaponin G", linewidth=3.0)
plt.plot(x3,y3, 'k', label="p75NTR", linewidth=3.0)
# plt.xlabel("Residue", fontsize=30)
# plt.ylabel("RMSF", fontsize=30)
# plt.title("RMSF Plot", fontsize=30)
#plt.legend(fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig("rmsf_bacopa.png", dpi=600)
plt.show()
